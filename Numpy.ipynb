# %% [markdown]
# <a href="https://colab.research.google.com/github/mn-ethel/Numpy-pratice/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy Vs Lists -comparison of processing time taken

# %%
import numpy as np

# %%
from time import process_time

# %% [markdown]
# Time taken by a list

# %%
python_list=[i for i in range(1000)]
start_time=process_time()
python_list=[i+5 for i in  python_list]
end_time=process_time()
print(end_time-start_time)
# Out:
# 0.0001407929999999169

# %% [markdown]
# Time taken by NumPy array

# %%
np_array=np.array([i for i in range(1000)])
start_time=process_time()
np_array+=5
end_time=process_time()
print(end_time-start_time)
# Out:
# 0.0009215179999984002
